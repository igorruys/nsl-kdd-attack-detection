# %% [markdown]
# # Classes e funções auxiliares

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import winsound
from sklearn.preprocessing import StandardScaler

#Classes que englobam os ataques que estao nos dados de treinamento e nos dados de teste
attack_classes = {'dos':['apache2','back','land','mailbomb','neptune','pod','processtable','smurf','teardrop','udpstorm'],
                  'probe':['ipsweep','mscan','nmap','portsweep','saint','satan'],
                  'u2r':['buffer_overflow','loadmodule','perl','rootkit','httptunnel','ps','sqlattack','xterm'],
                  'r2l':['ftp_write','guess_passwd','imap','multihop','phf','spy','warezclient','warezmaster','sendmail','named','snmpgetattack','snmpguess','xlock','xsnoop','worm']}

def beep():
    frequency = 2500
    duration = 1000
    winsound.Beep(frequency, duration)
    
    
def filterArray(x,y,clusts,cats=None):
    '''
    x: array of features
    y: one-dimensional array of labels
    cluts: one-dimensional array with cluster indexes for each connexion
    Filters arrays x (features) and y (labels) according to different clusters given in cluts. It returns an list in which
    each element is a tuple containing arrays x and y of each cluster and the index of the cluster.
    The function by default returns a dictionary of size n, where n is the number of different clusters. If cats is specified,
    the function return a list only containing the tuples corresponding to the cluster indexes idicated in cats, which should
    be a lista of cluster indexes.
    '''
    if cats is None:
        cats = list(np.unique(clusts))
    arrays = {}
    for cat in cats:
        inds = clusts == cat
        xFilt = x[inds]
        yFilt = y[inds]
        arrays[cat] = (xFilt,yFilt)
    return arrays
    
def printClusters(clusters):
    '''
    clusters: list/array of cluster indexes. Each element corresponds to a connexion.
    The function do the count of clusters of each type and counts the number of attacks and normal connexions in each
    cluster. It then prints a table with these counts.
    '''
    print("N | Count | Normal | Attacks")
    for cluster_i in clusters.keys():
        cluster = clusters[cluster_i]
        (u,counts)  = np.unique(cluster[1], return_counts=True)
        if len(u) == 2:
                tabCount = 4 - int(np.floor(np.log10(len(cluster[1]))))
                tabNorm  = 5 - int(np.floor(np.log10(counts[0])))
                print(cluster_i,"|",len(cluster[1])," "*tabCount + "|",counts[0]," "*tabNorm + "|", counts[1])
        else:
            if u[0] == 0:
                tabCount = 4 - int(np.floor(np.log10(len(cluster[1]))))
                tabNorm  = 5 - int(np.floor(np.log10(counts[0])))
                print(cluster_i,"|",len(cluster[1])," "*tabCount + "|",counts[0]," "*tabNorm + "|", 0)
            else:
                tabCount = 4 - int(np.floor(np.log10(len(cluster[1]))))
                print(cluster_i,"|",len(cluster[1])," "*tabCount + "|",0," "*5 + "|", counts[0])
                
def assClfsToClusters(clusters_train, AR, n_estimators=50, max_depth=20, max_features="sqrt"):
    #Contains the RF classifiers for clusters with more than 25 samples and at least 1 attack sample and 1 normal sample
    km_rf_clfs = {}
    #For all the other clusters, we assign a label according to the class of the majority of the samples 
    km_n_clfs  = {}
    step = 1

    filt_features = filterByAR(AR,0.05)
    
    rf_clf = RandomForestClassifier(n_estimators=n_estimators, max_depth=max_depth, max_features=max_features, random_state=1)

    #Fill km_rf_clfs with Random Forest classifiers for each cluster and km_n_clfs with the corresponding label
    for cluster_i in clusters_train.keys():
        print("Step ",step)

        x = clusters_train[cluster_i][0][filt_features] #features of current cluster
        y = clusters_train[cluster_i][1] #labels of current cluster
        m = len(y) #number of samples in current cluster

        (unique,counts)  = np.unique(y, return_counts=True)

        if m > 25 and len(unique) == 2:
            rf_clf.fit(x,y)
            km_rf_clfs[cluster_i] = rf_clf
        else:
            if m <= 25:
                km_n_clfs[cluster_i] = 1
            elif len(y[y==0]) > len(y[y==1]):
                km_n_clfs[cluster_i] = 0
            else:
                km_n_clfs[cluster_i] = 1

        step += 1
    return (km_rf_clfs,km_n_clfs)


def assClfsToClusters2(clusters_train, n_estimators=50, max_depth=20, max_features="sqrt", random_state=1):
    #Contains the RF classifiers for clusters with more than 25 samples and at least 1 attack sample and 1 normal sample
    km_rf_clfs = {}
    #For all the other clusters, we assign a label according to the class of the majority of the samples 
    km_n_clfs  = {}
    step = 1

    filt_features = features_sc
    
    rf_clf = RandomForestClassifier(n_estimators=n_estimators, max_depth=max_depth, max_features=max_features, random_state=random_state)

    #Fill km_rf_clfs with Random Forest classifiers for each cluster and km_n_clfs with the corresponding label
    for cluster_i in clusters_train.keys():
        print("Step ",step)

        x = clusters_train[cluster_i][0][filt_features] #features of current cluster
        y = clusters_train[cluster_i][1] #labels of current cluster
        m = len(y) #number of samples in current cluster

        (unique,counts)  = np.unique(y, return_counts=True)

        if m > 25 and len(unique) == 2:
            rf_clf.fit(x,y)
            km_rf_clfs[cluster_i] = rf_clf
        else:
            if m <= 25:
                km_n_clfs[cluster_i] = 1
            elif len(y[y==0]) > len(y[y==1]):
                km_n_clfs[cluster_i] = 0
            else:
                km_n_clfs[cluster_i] = 1

        step += 1
    return (km_rf_clfs,km_n_clfs)


def clustersPredict(x,clusters_ind,km_rf_clfs,km_n_clfs):
    
    y_prob = np.ones(np.shape(x)[0])*(-1)
    
    for cluster_i in km_rf_clfs.keys():
        inds = clusters_ind == cluster_i
        y_prob[inds] = km_rf_clfs[cluster_i].predict_proba(x[inds])[:,1]
    
    for cluster_i in km_n_clfs:
        inds = clusters_ind == cluster_i
        y_prob[inds] = km_n_clfs[cluster_i]
        
    return y_prob


def calcAR(df,feature_cols,label_col):
    col_type = getColType(df,list(set(df.columns) - set(feature_cols)))
    labels = list(set(list(df[label_col])))
    AR = {}
    
    for col in col_type['numeric']:
        avg   = df[col].mean()
        crs = []
        if avg == 0:
            AR[col] = 0
            continue
        for label in labels:
            crs.append(df.loc[df[label_col] == label, col].mean() / avg)
        AR[col] = max(crs)
        
    for col in col_type['binary']:
        zero = min(df[col])
        one  = max(df[col])
        crs = []
        for label in labels:
            subset = df.loc[df['class5']==label,col]
            f_zero = np.sum(subset == zero)
            f_one  = np.sum(subset == one)
            if f_zero == 0:
                crs.append(1000.0)
                continue
            crs.append(f_one/f_zero)
        AR[col] = max(crs)
    return AR



def filterByAR(AR,min_ar):
    filtred_features = {}
    for key in AR.keys():
        if AR[key] >= min_ar:
            filtred_features[key] = AR[key]
    return list(filtred_features.keys())
            

def getColType(df,labels_col):
    col_type = {'categorical':[],
                'binary':[],
                'numeric':[]}
    
    for col in list(df.drop(columns=labels_col).columns):
        if df[col].dtype == 'O':
            col_type['categorical'].append(col)
        elif len(list(df[col].value_counts().index)) == 2:
            col_type['binary'].append(col)
        else:
            col_type['numeric'].append(col)
    return col_type

def printMetrics(y_yh,legend):
    metrics = {}
    table = pd.DataFrame()
    i = 0
    for pair in y_yh:
        metrics = []
        metrics.append(accuracy_score(pair[0],pair[1]))
        fpr, tpr, thresholds = roc_curve(pair[0],pair[1])
        metrics += [tpr[1],fpr[1]]
        metrics.append(roc_auc_score(pair[0],pair[1]))
        metrics.append(f1_score(pair[0],pair[1]))
        metrics.append(precision_score(pair[0],pair[1]))
        
        table[legend[i]] = metrics 
        i += 1
    table.index = ["Accuracy", "TPR","FPR", "AUC", "F1 Score", "Precisão"]
    
    return table


def analyseThresholds(y,yprob,thList=None):
    if thList is None:
        thList = [1e-3, 5e-3, 1e-2, 5e-2, 1e-1, 5e-1]
    metrics = {"f1":[],'prec':[],'tpr':[],'fpr':[],'acc':[],'auc':[]}
    
    for th in thList:
        ypred = yprob > th
        metrics['acc'].append(accuracy_score(y,ypred))
        fpr, tpr, thresholds = roc_curve(y,ypred)
        metrics['tpr'].append(tpr[1])
        metrics['fpr'].append(fpr[1])
        metrics['auc'].append(roc_auc_score(y,ypred))
        metrics['f1'].append(f1_score(y,ypred))
        metrics['prec'].append(precision_score(y,ypred))
    y = np.array(list(metrics.values())).T
    plt.semilogx(thList,y)
    plt.grid()
    plt.legend(['F1','Prec','TPR','FPR','Acc','AuC'])

# %% [markdown]
# # Importing Data

# %% [markdown]
# Os nomes de cada coluna (feauture) não vieram diretamente no arquivo dos dados, então eles foram inseridos manualmente.

# %%
pd.set_option('display.max_columns', None)
pd.reset_option('max_rows')

headers = ['duration', 'protocol_type', 'service', 'flag', 'src_bytes', 'dst_bytes', 'land', 'wrong_fragment', 
           'urgent', 'hot', 'num_failed_logins', 'logged_in', 'num_compromised', 'root_shell', 'su_attempted',
           'num_root', 'num_file_creations', 'num_shells', 'num_access_files', 'num_outbound_cmds', 'is_host_login',
           'is_guest_login', 'count', 'srv_count', 'serror_rate', 'srv_serror_rate', 'rerror_rate', 'srv_rerror_rate',
           'same_srv_rate', 'diff_srv_rate', 'srv_diff_host_rate', 'dst_host_count', 'dst_host_srv_count',
           'dst_host_same_srv_rate', 'dst_host_diff_srv_rate', 'dst_host_same_src_port_rate',
           'dst_host_srv_diff_host_rate', 'dst_host_serror_rate', 'dst_host_srv_serror_rate', 'dst_host_rerror_rate',
           'dst_host_srv_rerror_rate','event_type','event_score']\

labels = ['event_type','event_score']

df_train = pd.read_csv("NSL-KDD/KDDTrain+.txt",names=headers)
df_test = pd.read_csv("NSL-KDD/KDDTest+.txt",names=headers)

col_type = getColType(df_train,labels)

# %%
len(col_type['numeric'])
# Out:
# 31

# %% [markdown]
# # Preprocessing Data

# %% [markdown]
# In this step, we add the columns <b>class5</b> (labels belonging to 5 different classes: normal, DoS, probe, U2R or R2L) and <b>class2</b> (labels belonging to 2 different classes: normal or attack).

# %%
df_train = df_train.drop(labels='event_score',axis=1)
df_test  = df_test.drop(labels='event_score',axis=1)

event_train = df_train['event_type']
event_test = df_test['event_type']
(df_train['class5'],df_test['class5']) = (0,0)
(df_train.loc[event_train.isin(attack_classes['dos']), 'class5'],df_test.loc[event_test.isin(attack_classes['dos']), 'class5']) = (1,1)
(df_train.loc[event_train.isin(attack_classes['probe']), 'class5'],df_test.loc[event_test.isin(attack_classes['probe']), 'class5']) = (2,2)
(df_train.loc[event_train.isin(attack_classes['u2r']), 'class5'],df_test.loc[event_test.isin(attack_classes['u2r']), 'class5']) = (3,3)
(df_train.loc[event_train.isin(attack_classes['r2l']), 'class5'],df_test.loc[event_test.isin(attack_classes['r2l']), 'class5']) = (4,4)

(df_train['class2'],df_test['class2']) = (0,0)
(df_train.loc[event_train != 'normal', 'class2'] ,df_test.loc[event_test != 'normal', 'class2']) = (1,1)

if not('class2') in labels:
    labels.extend(['class2','class5'])
    labels.remove('event_score')

# %%
#This cell is dedicated to printing the table with different counts, shown below
gen_dict = {'Total': [len(df_train),len(df_test)],
            'Normal':[np.sum(df_train.class2 == 0),np.sum(df_test.class2 == 0)],
            'Attack':[np.sum(df_train.class2 == 1),np.sum(df_test.class2 == 1)],
            'DoS':   [np.sum(df_train.class5 == 1),np.sum(df_test.class5 == 1)],
            'Probe': [np.sum(df_train.class5 == 2),np.sum(df_test.class5 == 2)],
            'U2R':   [np.sum(df_train.class5 == 3),np.sum(df_test.class5 == 3)],
            'R2L':   [np.sum(df_train.class5 == 4),np.sum(df_test.class5 == 4)]}
gen_table = pd.DataFrame(data=gen_dict,index=['Train','Test'])
gen_table
# Out:
#         Total  Normal  Attack    DoS  Probe  U2R   R2L
# Train  125973   67343   58630  45927  11656   52   995
# Test    22544    9711   12833   7458   2421  200  2754

# %% [markdown]
# Abaixo, observamos a contagem de elementos na coluna <i>su_attempted</i>. Essa coluna indica se o comando "su_root" foi usado ou não. Portanto, essa coluna deveria conter apenas valores 0 ou 1, porém, vemos que alguns valores são iguais a 2. Isso será corrigido mais para frente.

# %% [markdown]
# # Preparação dos Dados

# %% [markdown]
# Eliminamos a coluna <i>num_outbound_cms</i>, pois todos seus valores são iguais a zero.

# %%
if 'num_outbound_cmds' in df_train.columns:
    del df_train['num_outbound_cmds']
    col_type['numeric'].remove('num_outbound_cmds')
if 'num_outbound_cmds' in df_test.columns:
    del df_test['num_outbound_cmds']

# %% [markdown]
# Corrigimos a coluna <i>su_attempted</i>, substituindo os valores iguais a 2 por 1.

# %%
df_train['su_attempted'] = df_train['su_attempted'].replace(2,1)
df_test['su_attempted']  = df_test['su_attempted'].replace(2,1)

if 'su_attempted' in col_type['numeric'] and not('su_attempted' in col_type['binary']):
    col_type['binary'].append('su_attempted')
    col_type['numeric'].remove('su_attempted')

# %% [markdown]
# Nessa parte é realizada uma codificação one-hot nas colunas com valores string e os valores foram normalizados.
# Nos dados de treinamento, agora, existem 6 features que não existem nos dados de teste. Isso aconteceu porque quando foi feito o one-hot encoding, alguns labels não existiam nos dados de test. São os labels mostrados abaixo (todos da coluna service).

# %%
from sklearn.model_selection import train_test_split

#we apply one-hot encoding to the trainning dataset
df_train_ohe = pd.get_dummies(df_train,columns=['protocol_type','service','flag'])

#we apply one-hot encoding to the test dataset and we add the 6 columns that were missing
df_test_ohe  = pd.get_dummies(df_test,columns=['protocol_type','service','flag'])
df_test_ohe[['service_http_2784', 'service_harvest', 'service_aol', 'service_http_8001', 'service_urh_i', 'service_red_i']] = 0

#list of features of the dataset after apply one-hot econding
features_ohe = list(df_train_ohe.columns)[:]
for col in labels:
    features_ohe.remove(col)

#column type (numeric, categorical, binary) after applyign one-hot encoding
col_type_ohe = getColType(df_train_ohe,labels)

# %% [markdown]
# A cross validation dataset is created by splitting the trainning dataset (20% for cross validation).

# %%
from sklearn.model_selection import train_test_split

df_train_ohe_split, df_cv_ohe_split = train_test_split(df_train_ohe, test_size=0.2, random_state=1)
df_train_ohe_split.index = range(len(df_train_ohe_split.index))
df_cv_ohe_split.index = range(len(df_cv_ohe_split.index))

# %%
#standardization of the features of both datasets
ft_train = pd.DataFrame(StandardScaler().fit_transform(df_train_ohe_split[features_ohe]),columns=features_ohe)
ft_cv    = pd.DataFrame(StandardScaler().fit_transform(df_cv_ohe_split[features_ohe]),columns=features_ohe)
ft_test  = pd.DataFrame(StandardScaler().fit_transform(df_test_ohe[features_ohe]),columns=features_ohe)

#concatenation of the standardized features with the label columns
df_train_sc = pd.concat([ft_train,df_train_ohe_split[labels]],axis=1)
df_cv_sc    = pd.concat([ft_cv,df_cv_ohe_split[labels]],axis=1)
df_test_sc  = pd.concat([ft_test,df_test_ohe[labels]],axis=1)

# %% [markdown]
# In this part, we index the binary features with ones and zeros, since these binary columns were standardized and are no longer 0's and 1's.

# %%
for col in col_type_ohe['binary']:
    (zero_train, zero_cv, zero_test) = (min(df_train_sc[col]), min(df_cv_sc[col]), min(df_test_sc[col]))
    (one_train, one_cv, one_test)   = (max(df_train_sc[col]), max(df_cv_sc[col]), max(df_test_sc[col]))
    
    df_train_sc.loc[df_train_sc[col] == zero_train, col] = 0
    df_train_sc.loc[df_train_sc[col] == one_train, col] = 1
    
    df_cv_sc.loc[df_cv_sc[col] == zero_cv, col] = 0
    df_cv_sc.loc[df_cv_sc[col] == one_cv, col] = 1
    
    df_test_sc.loc[df_test_sc[col] == zero_test, col] = 0
    df_test_sc.loc[df_test_sc[col] == one_test, col] = 1

# %%
features_sc = df_train_sc.columns[:-3]

# %% [markdown]
# We filter the features by AR.

# %%
AR = calcAR(df_train_ohe,list(set(df_train_sc) - set(labels)),'class5')
filtered_features = filterByAR(AR,0.01)

# %%
df_train_ar = df_train_sc[filtered_features + labels]
df_test_ar  = df_test_sc[filtered_features + labels]
df_cv_ar    = df_cv_sc[filtered_features + labels]

# %%
table = pd.DataFrame(columns=['Train','CV'])
table.Train = df_train_ar.class5.value_counts()
table.CV = df_cv_ar.class5.value_counts()
table
# Out:
#    Train     CV
# 0  53837  13506
# 1  36811   9116
# 2   9311   2345
# 4    780    215
# 3     39     13

# %% [markdown]
# # PCA

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components = 5)
X2D = pca.fit_transform(df_train_ar[filterByAR(AR,0.05)])
#X2D = pca.fit_transform(df_train_ohe[features_ohe])

# %%
# %matplotlib notebook
n = len(X2D)
p = int(n/15)
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.scatter(X2D[0:p,0], X2D[0:p,1], zs=X2D[0:p,4], c=df_train_ar.class5[0:p], cmap="Set3")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
n = len(X2D)
p = int(n/10)
plt.scatter(x=X2D[0:p,0], y=X2D[0:p,1], c=df_train_ar.class5[0:p])
plt.grid()
# Out:
# <img src="data:," width="0">

# %% [markdown]
# # KMeans + Random Forest

# %% [markdown]
# ## KMeans

# %%
from sklearn.cluster import KMeans

filt_ft_KM = filterByAR(AR,0.1) #filtering features with threshold = 0.1
features_KM = list(set(filt_ft_KM).intersection(set(col_type['numeric'])))

(x_train_KM, y_train_KM) = (df_train_sc[features_KM], df_train_sc['class2'])
(x_cv_KM, y_cv_KM) = (df_cv_sc[features_KM], df_cv_sc['class2'])
(x_test_KM, y_test_KM) = (df_test_sc[features_KM], df_test_sc['class2'])


kmeans = KMeans(n_clusters = 8, max_iter=100, n_init=25, algorithm='full', random_state=1)
kmeans.fit(x_train_KM)
kmeans.n_iter_
# Out:
# 6

# %%
clusters_train_ind = kmeans.predict(x_train_KM)
clusters_cv_ind    = kmeans.predict(x_cv_KM)
clusters_test_ind  = kmeans.predict(x_test_KM)

clusters_train = filterArray(df_train_ar, y_train_KM, clusters_train_ind)
clusters_cv    = filterArray(df_cv_ar,    y_cv_KM,    clusters_cv_ind)
clusters_test  = filterArray(df_test_ar,  y_test_KM , clusters_test_ind)

#prints a table with the counts for each cluster
print("Counts for each cluster:",'\n')
print("==== Trainning dataset ====")
printClusters(clusters_train)

print('\n',"==== Test dataset ====")
printClusters(clusters_test)
# Out:
# Counts for each cluster:
#
# ==== Trainning dataset ====
# N | Count | Normal | Attacks
# 0 | 51611 | 46795  | 4816
# 1 | 11365 | 2198   | 9167
# 2 | 27945 | 94     | 27851
# 3 | 7797  | 4269   | 3528
# 4 | 699   | 0      | 699
# 5 | 1     | 1      | 0
# 6 | 704   | 60     | 644
# 7 | 656   | 420    | 236
#
#  ==== Test dataset ====
# N | Count | Normal | Attacks
# 0 | 13955 | 8871   | 5084
# 1 | 4602  | 73     | 4529
# 2 | 2497  | 29     | 2468
# 3 | 1381  | 663    | 718
# 4 | 66    | 43     | 23
# 6 | 16    | 14     | 2
# 7 | 27    | 18     | 9

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

#Assigns Random Tree classifieers to category 1 clusters and 1 or 0 to category 2 clusters
#km_rf_clfs: dictionary with category 1 clusters, containing Random Tree classifiers
#km_n_clfs: dictionary  with category 2 clusters, containing 1 or 0, depending on majority rule
(km_rf_clfs_train,km_n_clfs_train) = assClfsToClusters(clusters_train, AR)
(km_rf_clfs_cv,km_n_clfs_cv)       = assClfsToClusters(clusters_cv, AR)
(km_rf_clfs_test,km_n_clfs_test)   = assClfsToClusters(clusters_test, AR)

beep()
# Out:
# Step  1
# Step  2
# Step  3
# Step  4
# Step  5
# Step  6
# Step  7
# Step  8
# Step  1
# Step  2
# Step  3
# Step  4
# Step  5
# Step  6
# Step  7
# Step  1
# Step  2
# Step  3
# Step  4
# Step  5
# Step  6
# Step  7

# %%
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score, roc_curve, roc_auc_score
x_train = df_train_ar[filterByAR(AR,0.05)]
x_cv    = df_cv_ar[filterByAR(AR,0.05)]
x_test  = df_test_ar[filterByAR(AR,0.05)] 

yh_train_KM = clustersPredict(x_train, clusters_train_ind, km_rf_clfs_train,km_n_clfs_train) > 0.5
yh_cv_KM  = clustersPredict(x_cv, clusters_cv_ind, km_rf_clfs_cv,km_n_clfs_cv) > 0.5
yh_test_KM  = clustersPredict(x_test, clusters_test_ind, km_rf_clfs_test,km_n_clfs_test) > 0.3 #0.3
    
beep()
printMetrics([(y_train_KM,yh_train_KM),(y_cv_KM,yh_cv_KM),(y_test_KM,yh_test_KM)],["Trainning","CV","Test"])
# Out:
#           Trainning        CV      Test
# Accuracy   0.378436  0.520262  0.484297
# TPR        0.077310  0.718282  0.164030
# FPR        0.359010  0.651118  0.092472
# AUC        0.359150  0.533582  0.535779
# F1 Score   0.103837  0.581461  0.265850
# Precisão   0.158078  0.488424  0.700966

# %%
np.shape(x_train)
# Out:
# (100778, 51)

# %% [markdown]
# # Teste

# %%
from sklearn.cluster import KMeans

(x_train_KM, y_train_KM) = (df_train_sc[features_sc], df_train_sc['class2'])
(x_cv_KM, y_cv_KM) = (df_cv_sc[features_sc], df_cv_sc['class2'])
(x_test_KM, y_test_KM) = (df_test_sc[features_sc], df_test_sc['class2'])


kmeans = KMeans(n_clusters = 8, max_iter=100, n_init=25, algorithm='full', random_state=10) 
kmeans.fit(x_train_KM)
kmeans.n_iter_
# Out:
# 15

# %%
clusters_train_ind = kmeans.predict(x_train_KM)
clusters_cv_ind    = kmeans.predict(x_cv_KM)
clusters_test_ind  = kmeans.predict(x_test_KM)

clusters_train = filterArray(df_train_sc, y_train_KM, clusters_train_ind)
clusters_cv    = filterArray(df_cv_sc,    y_cv_KM,    clusters_cv_ind)
clusters_test  = filterArray(df_test_sc,  y_test_KM , clusters_test_ind)

#prints a table with the counts for each cluster
print("Counts for each cluster:",'\n')
print("==== Trainning dataset ====")
printClusters(clusters_train)

print('\n',"==== Test dataset ====")
printClusters(clusters_test)
# Out:
# Counts for each cluster:
#
# ==== Trainning dataset ====
# N | Count | Normal | Attacks
# 0 | 43545 | 42115  | 1430
# 1 | 27965 | 91     | 27874
# 2 | 12059 | 2255   | 9804
# 3 | 7391  | 5401   | 1990
# 4 | 1     | 1      | 0
# 5 | 699   | 0      | 699
# 6 | 656   | 420    | 236
# 7 | 8462  | 3554   | 4908
#
#  ==== Test dataset ====
# N | Count | Normal | Attacks
# 0 | 12281 | 8139   | 4142
# 1 | 2400  | 21     | 2379
# 2 | 4666  | 77     | 4589
# 3 | 1496  | 944    | 552
# 5 | 62    | 41     | 21
# 6 | 27    | 18     | 9
# 7 | 1612  | 471    | 1141

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

#Assigns Random Tree classifieers to category 1 clusters and 1 or 0 to category 2 clusters
#km_rf_clfs: dictionary with category 1 clusters, containing Random Tree classifiers
#km_n_clfs: dictionary  with category 2 clusters, containing 1 or 0, depending on majority rule
(km_rf_clfs_train,km_n_clfs_train) = assClfsToClusters2(clusters_train)
(km_rf_clfs_cv,km_n_clfs_cv)       = assClfsToClusters2(clusters_cv)
(km_rf_clfs_test,km_n_clfs_test)   = assClfsToClusters2(clusters_test)

beep()
# Out:
# Step  1
# Step  2
# Step  3
# Step  4
# Step  5
# Step  6
# Step  7
# Step  8
# Step  1
# Step  2
# Step  3
# Step  4
# Step  5
# Step  6
# Step  7
# Step  1
# Step  2
# Step  3
# Step  4
# Step  5
# Step  6
# Step  7

# %%
yprob_train_KM = clustersPredict(x_train_KM, clusters_train_ind, km_rf_clfs_train,km_n_clfs_train)
yprob_cv_KM  = clustersPredict(x_cv_KM, clusters_cv_ind, km_rf_clfs_cv,km_n_clfs_cv)
yprob_test_KM  = clustersPredict(x_test_KM, clusters_test_ind, km_rf_clfs_test,km_n_clfs_test)

# %%
#Metric analyses for the cv dataset for different thresholds
# %matplotlib inline
analyseThresholds(y_cv_KM,yprob_cv_KM,np.arange(1e-4,0.95,5e-3))

# %%
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score, roc_curve, roc_auc_score

ypred_train_KM = yprob_train_KM > 0.5
ypred_cv_KM  = yprob_cv_KM > 0.27
ypred_test_KM  = yprob_test_KM > 0.27
    
beep()
printMetrics([(y_train_KM,ypred_train_KM),(y_cv_KM,ypred_cv_KM),(y_test_KM,ypred_test_KM)],["Trainning","CV","Test"])
# Out:
#           Trainning        CV      Test
# Accuracy   0.962492  0.955428  0.927741
# TPR        0.922094  0.966721  0.910855
# FPR        0.002285  0.054346  0.049943
# AUC        0.959905  0.956187  0.930456
# F1 Score   0.958162  0.952662  0.934858
# Precisão   0.997166  0.939006  0.960161

# %% [markdown]
# # Classificação por Classe

# %% [markdown]
# ## Random Forest

# %% [markdown]
# ### DoS

# %%
mask_dos = (df_train_ohe_split.class5 == 1) | (df_train_ohe_split.class5 == 0)    

(x_train_dos, y_train_dos) = (df_train_sc.loc[:, features_sc], df_train_sc.loc[:,'class2'])

(x_cv_dos, y_cv_dos) = (df_cv_sc.loc[:, features_sc], df_cv_sc.loc[:,'class2'])

(x_test_dos, y_test_dos) = (df_test_sc.loc[:, features_sc], df_test_sc.loc[:,'class2'])

# %%
from sklearn.ensemble import RandomForestClassifier

rf_clf = RandomForestClassifier(n_estimators=400, max_depth=20, random_state=1)
rf_clf.fit(x_train_dos.loc[mask_dos],y_train_dos.loc[mask_dos])

beep()

# %%
yprob_train_dos = rf_clf.predict_proba(x_train_dos)[:,1]
yprob_cv_dos    = rf_clf.predict_proba(x_cv_dos)[:,1]
yprob_test_dos  = rf_clf.predict_proba(x_test_dos)[:,1]

# %%
#Metric analyses for the cv dataset for different thresholds
# %matplotlib inline
analyseThresholds(y_cv_dos,yprob_cv_dos)

# %%
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score, roc_curve, roc_auc_score

yh_train_dos = yprob_train_dos > 0.5
yh_cv_dos    = yprob_cv_dos > 0.1
yh_test_dos  = yprob_test_dos > 0.1

printMetrics([(y_train_dos,yh_train_dos),(y_cv_dos,yh_cv_dos),(y_test_dos,yh_test_dos)],["Trainning","CV","Test"])
# Out:
#           Trainning        CV      Test
# Accuracy   0.921967  0.963326  0.814363
# TPR        0.832513  0.925400  0.813216
# FPR        0.000037  0.003850  0.184121
# AUC        0.916238  0.960775  0.814547
# F1 Score   0.908582  0.959039  0.832981
# Precisão   0.999949  0.995216  0.853730

# %% [markdown]
# ### Probe

# %%
mask_probe = (df_train_ohe.class5 == 2) | (df_train_ohe.class5 == 0)

(x_train_probe, y_train_probe) = (df_train_sc.loc[:, features_sc], df_train_sc.loc[:,'class2'])

(x_cv_probe, y_cv_probe) = (df_cv_sc.loc[:, features_sc], df_cv_sc.loc[:,'class2'])

(x_test_probe, y_test_probe) = (df_test_sc.loc[:, features_sc], df_test_sc.loc[:,'class2'])

# %%
from sklearn.ensemble import RandomForestClassifier

rf_clf_probe = RandomForestClassifier(n_estimators=500, max_depth=20, max_features="sqrt", random_state=1)
rf_clf_probe.fit(x_train_probe.loc[mask_probe],y_train_probe[mask_probe])

beep()

# %%
yprob_train_probe = rf_clf_probe.predict_proba(x_train_probe)[:,1]
yprob_cv_probe    = rf_clf_probe.predict_proba(x_cv_probe)[:,1]
yprob_test_probe  = rf_clf_probe.predict_proba(x_test_probe)[:,1]

# %%
#Metric analyses for the cv dataset for different thresholds
# %matplotlib inline
analyseThresholds(y_cv_probe,yprob_cv_probe,np.arange(1e-4,0.95,5e-3))

# %%
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score, roc_curve, roc_auc_score

yh_train_probe = yprob_train_probe > 0.5
yh_cv_probe    = yprob_cv_probe > 0.3
yh_test_probe  = yprob_test_probe > 0.3

printMetrics([(y_train_probe,yh_train_probe),(y_cv_probe,yh_cv_probe),(y_test_probe,yh_test_probe)],["Trainning","CV","Test"])
# Out:
#           Trainning        CV      Test
# Accuracy   0.999295  0.991427  0.847720
# TPR        0.998764  0.985285  0.886387
# FPR        0.000241  0.003258  0.203378
# AUC        0.999261  0.991014  0.841505
# F1 Score   0.999243  0.990710  0.868884
# Precisão   0.999723  0.996194  0.852060

# %% [markdown]
# ### U2R + R2L

# %%
mask_u2r_r2l = (df_train_ohe.class5 == 3) | (df_train_ohe.class5 == 4) | (df_train_ohe.class5 == 0)

(x_train_u2r_r2l, y_train_u2r_r2l) = (df_train_sc.loc[:, features_sc], df_train_sc.loc[:,'class2'])

(x_cv_u2r_r2l, y_cv_u2r_r2l) = (df_cv_sc.loc[:, features_sc], df_cv_sc.loc[:,'class2'])

(x_test_u2r_r2l, y_test_u2r_r2l) = (df_test_sc.loc[:, features_sc], df_test_sc.loc[:,'class2'])

# %%
from sklearn.ensemble import RandomForestClassifier

rf_clf_u2r_r2l = RandomForestClassifier(n_estimators=500, max_depth=20, max_features="sqrt", random_state=1)
rf_clf_u2r_r2l.fit(x_train_u2r_r2l.loc[mask_u2r_r2l],y_train_u2r_r2l.loc[mask_u2r_r2l])

beep()

# %%
yprob_train_u2r_r2l = rf_clf_u2r_r2l.predict_proba(x_train_u2r_r2l)[:,1]
yprob_cv_u2r_r2l    = rf_clf_u2r_r2l.predict_proba(x_cv_u2r_r2l)[:,1]
yprob_test_u2r_r2l  = rf_clf_u2r_r2l.predict_proba(x_test_u2r_r2l)[:,1]

# %%
#Metric analyses for the cv dataset for different thresholds
# %matplotlib inline
analyseThresholds(y_cv_u2r_r2l,yprob_cv_u2r_r2l,np.arange(1e-4,0.95,5e-3))

# %%
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score, roc_curve, roc_auc_score

yh_train_u2r_r2l = yprob_train_u2r_r2l > 0.5
yh_cv_u2r_r2l    = yprob_cv_u2r_r2l > 0.3
yh_test_u2r_r2l  = yprob_test_u2r_r2l > 0.33

printMetrics([(y_train_u2r_r2l,yh_train_u2r_r2l),(y_cv_u2r_r2l,yh_cv_u2r_r2l),(y_test_u2r_r2l,yh_test_u2r_r2l)],["Trainning","CV","Test"])
# Out:
#           Trainning        CV      Test
# Accuracy   0.999137  0.992022  0.842796
# TPR        0.998487  0.986825  0.848593
# FPR        0.000297  0.003480  0.164865
# AUC        0.999095  0.991673  0.841864
# F1 Score   0.999073  0.991363  0.860054
# Precisão   0.999659  0.995942  0.871828

# %% [markdown]
# ### Combination of classifiers

# %%
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score

eventClasses = ['Normal','R2L']
eventClassesInd = [0,1]

y_train_comb_prob = (yprob_train_dos + yprob_train_probe + yprob_train_u2r_r2l)/3
y_cv_comb_prob    = (yprob_cv_dos + yprob_cv_probe + yprob_cv_u2r_r2l)/3
y_test_comb_prob  = (yprob_test_dos + yprob_test_probe + yprob_test_u2r_r2l)/3

# %%
#Metric analyses for the cv dataset for different thresholds
# %matplotlib inline
#y_cv_dos == y_cv_prob == y_cv_u2r_r2l
analyseThresholds(y_cv_dos,y_cv_comb_prob,np.arange(1e-4,0.95,5e-3))

# %%
y_train_comb_pred = y_train_comb_prob > 0.5
y_cv_comb_pred    = y_cv_comb_prob > 0.3
y_test_comb_pred  = y_test_comb_prob > 0.25

printMetrics([(y_train_dos,y_train_comb_pred),
              (y_cv_dos,y_cv_comb_pred),
              (y_test_dos,y_test_comb_pred)],
             ["Trainning","CV","Test"])
# Out:
#           Trainning        CV      Test
# Accuracy   0.998254  0.991030  0.835078
# TPR        0.996400  0.981350  0.855373
# FPR        0.000130  0.000592  0.191741
# AUC        0.998135  0.990379  0.831816
# F1 Score   0.998122  0.990245  0.855173
# Precisão   0.999850  0.999303  0.854973

# %%
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score

eventClasses = ['Normal','R2L']
eventClassesInd = [0,1]

yh_train_comb = yh_train_dos | yh_train_probe | yh_train_u2r_r2l
yh_cv_comb    = yh_cv_dos | yh_cv_probe | yh_cv_u2r_r2l
yh_test_comb  = yh_test_dos | yh_test_probe | yh_test_u2r_r2l

printMetrics([(y_train_dos,yh_train_comb),(y_cv_dos,yh_cv_comb),(y_test_dos,yh_test_comb)],["Trainning","CV","Test"])
# Out:
#           Trainning        CV      Test
# Accuracy   0.999464  0.892876  0.824654
# TPR        0.999402  0.995164  0.875244
# FPR        0.000482  0.197047  0.242200
# AUC        0.999460  0.899059  0.816522
# F1 Score   0.999424  0.896823  0.850362
# Precisão   0.999445  0.816170  0.826855

# %% [markdown]
# ## Regressão Logística <a id='lr_classe'></a>

# %% [markdown]
# ### Treinamento

# %%
from sklearn.linear_model import LogisticRegression
import time

# %%
t1 = time.time()

print("Treinando DoS")
lrclass_dos = LogisticRegression(max_iter=400,tol=1e-4)
lrclass_dos.fit(x_train_dos,y_train_dos)
print("Treinando Probe")
lrclass_probe = LogisticRegression(max_iter=400,tol=5e-3,solver='saga')
lrclass_probe.fit(x_train_probe,y_train_probe)
print("Treinando U2R")
lrclass_u2r = LogisticRegression(max_iter=600,tol=2e-3,solver='saga')
lrclass_u2r.fit(x_train_u2r,y_train_u2r)
print("Treinando R2L")
lrclass_r2l = LogisticRegression(max_iter=600,tol=2e-3,solver='saga')
lrclass_r2l.fit(x_train_r2l,y_train_r2l)
print("Treinando U2R + R2L")
lrclass_u2r_r2l = LogisticRegression(max_iter=600,tol=2e-3,solver='saga')
lrclass_u2r_r2l.fit(x_train_u2r_r2l,y_train_u2r_r2l)


print("Tempo: %.1f s" % (time.time() - t1))
beep()

# %% [markdown]
# ### Avaliação - DoS

# %%
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score

eventClasses = ['Normal','DoS']
eventClassesInd = [0,1]

yh_train_dos = lrclass_dos.predict(x_train_dos)
yh_test_dos  = lrclass_dos.predict(x_test_dos)

#Acuracia
accTrain = accuracy_score(y_train_dos,yh_train_dos)
accTest = accuracy_score(y_test_dos,yh_test_dos)

#Recall
recTrain = recall_score(y_train_dos,yh_train_dos)
recTest  = recall_score(y_test_dos,yh_test_dos)

#Precision
precTrain = precision_score(y_train_dos,yh_train_dos)
precTest  = precision_score(y_test_dos,yh_test_dos)

#f1 score
f1Train = f1_score(y_train_dos,yh_train_dos)
f1Test  = f1_score(y_test_dos,yh_test_dos)

trainMetrics = np.array([accTrain, recTrain, precTrain, f1Train])
testMetrics  = np.array([accTest, recTest, precTest, f1Test])

table = pd.DataFrame()
table['Treinamento'] = trainMetrics
table['Teste'] = testMetrics
table.index = ["Acurácia", "Revocação", "Precisão","F1 Score"]
table

# %%
from sklearn.metrics import plot_confusion_matrix
plot_confusion_matrix(lrclass_dos,x_test_dos,y_test_dos)

# %% [markdown]
# ### Avaliação - Probe

# %%
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score

eventClasses = ['Normal','Probe']
eventClassesInd = [0,1]

yh_train_probe = lrclass_probe.predict(x_train_probe)
yh_test_probe  = lrclass_probe.predict(x_test_probe)

#Acuracia
accTrain = accuracy_score(y_train_probe,yh_train_probe)
accTest = accuracy_score(y_test_probe,yh_test_probe)

#Recall
recTrain = recall_score(y_train_probe,yh_train_probe)
recTest  = recall_score(y_test_probe,yh_test_probe)

#Precision
precTrain = precision_score(y_train_probe,yh_train_probe)
precTest  = precision_score(y_test_probe,yh_test_probe)

#f1 score
f1Train = f1_score(y_train_probe,yh_train_probe)
f1Test  = f1_score(y_test_probe,yh_test_probe)

trainMetrics = np.array([accTrain, recTrain, precTrain, f1Train])
testMetrics  = np.array([accTest, recTest, precTest, f1Test])

table = pd.DataFrame()
table['Treinamento'] = trainMetrics
table['Teste'] = testMetrics
table.index = ["Acurácia", "Revocação", "Precisão","F1 Score"]
table

# %%
from sklearn.metrics import plot_confusion_matrix
plot_confusion_matrix(lrclass_probe,x_test_probe,y_test_probe)

# %% [markdown]
# ### Avaliação - U2R

# %%
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score

eventClasses = ['Normal','U2R']
eventClassesInd = [0,1]

yh_train_u2r = lrclass_u2r.predict(x_train_u2r)
yh_test_u2r  = lrclass_u2r.predict(x_test_u2r)

#Acuracia
accTrain = accuracy_score(y_train_u2r,yh_train_u2r)
accTest = accuracy_score(y_test_u2r,yh_test_u2r)

#Recall
recTrain = recall_score(y_train_u2r,yh_train_u2r)
recTest  = recall_score(y_test_u2r,yh_test_u2r)

#Precision
precTrain = precision_score(y_train_u2r,yh_train_u2r)
precTest  = precision_score(y_test_u2r,yh_test_u2r)

#f1 score
f1Train = f1_score(y_train_u2r,yh_train_u2r)
f1Test  = f1_score(y_test_u2r,yh_test_u2r)

trainMetrics = np.array([accTrain, recTrain, precTrain, f1Train])
testMetrics  = np.array([accTest, recTest, precTest, f1Test])

table = pd.DataFrame()
table['Treinamento'] = trainMetrics
table['Teste'] = testMetrics
table.index = ["Acurácia", "Revocação", "Precisão","F1 Score"]
table

# %%
from sklearn.metrics import plot_confusion_matrix
plot_confusion_matrix(lrclass_u2r,x_test_u2r,y_test_u2r)

# %% [markdown]
# ### Avaliação - R2L

# %%
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score

eventClasses = ['Normal','R2L']
eventClassesInd = [0,1]

yh_train_r2l = lrclass_r2l.predict(x_train_r2l)
yh_test_r2l  = lrclass_r2l.predict(x_test_r2l)

#Acuracia
accTrain = accuracy_score(y_train_r2l,yh_train_r2l)
accTest = accuracy_score(y_test_r2l,yh_test_r2l)

#Recall
recTrain = recall_score(y_train_r2l,yh_train_r2l)
recTest  = recall_score(y_test_r2l,yh_test_r2l)

#Precision
precTrain = precision_score(y_train_r2l,yh_train_r2l)
precTest  = precision_score(y_test_r2l,yh_test_r2l)

#f1 score
f1Train = f1_score(y_train_r2l,yh_train_r2l)
f1Test  = f1_score(y_test_r2l,yh_test_r2l)

trainMetrics = np.array([accTrain, recTrain, precTrain, f1Train])
testMetrics  = np.array([accTest, recTest, precTest, f1Test])

table = pd.DataFrame()
table['Treinamento'] = trainMetrics
table['Teste'] = testMetrics
table.index = ["Acurácia", "Revocação", "Precisão","F1 Score"]
table

# %%
from sklearn.metrics import plot_confusion_matrix
plot_confusion_matrix(lrclass_r2l,x_test_r2l,y_test_r2l)

# %% [markdown]
# ### Avaliação - U2R  + R2L

# %%
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score

eventClasses = ['Normal','R2L']
eventClassesInd = [0,1]

yh_train_u2r_r2l = lrclass_u2r_r2l.predict(x_train_u2r_r2l)
yh_test_u2r_r2l  = lrclass_u2r_r2l.predict(x_test_u2r_r2l)

#Acuracia
accTrain = accuracy_score(y_train_u2r_r2l,yh_train_u2r_r2l)
accTest = accuracy_score(y_test_u2r_r2l,yh_test_u2r_r2l)

#Recall
recTrain = recall_score(y_train_u2r_r2l,yh_train_u2r_r2l)
recTest  = recall_score(y_test_u2r_r2l,yh_test_u2r_r2l)

#Precision
precTrain = precision_score(y_train_u2r_r2l,yh_train_u2r_r2l)
precTest  = precision_score(y_test_u2r_r2l,yh_test_u2r_r2l)

#f1 score
f1Train = f1_score(y_train_u2r_r2l,yh_train_u2r_r2l)
f1Test  = f1_score(y_test_u2r_r2l,yh_test_u2r_r2l)

trainMetrics = np.array([accTrain, recTrain, precTrain, f1Train])
testMetrics  = np.array([accTest, recTest, precTest, f1Test])

table = pd.DataFrame()
table['Treinamento'] = trainMetrics
table['Teste'] = testMetrics
table.index = ["Acurácia", "Revocação", "Precisão","F1 Score"]
table

# %%
from sklearn.metrics import plot_confusion_matrix
plot_confusion_matrix(lrclass_u2r_r2l,x_test_u2r_r2l,y_test_u2r_r2l)

# %% [markdown]
# ### Combinação dos classificadores

# %%
yprob_train_lr = {'dos':lrclass_dos.predict_proba(x_train)[:,1],
                  'probe':lrclass_probe.predict_proba(x_train)[:,1],
                  'u2r':lrclass_u2r.predict_proba(x_train)[:,1],
                  'r2l':lrclass_r2l.predict_proba(x_train)[:,1],
                  'u2r_r2l':lrclass_u2r_r2l.predict_proba(x_train)[:,1]}

yprob_test_lr = {'dos':lrclass_dos.predict_proba(x_test)[:,1],
                 'probe':lrclass_probe.predict_proba(x_test)[:,1],
                 'u2r':lrclass_u2r.predict_proba(x_test)[:,1],
                 'r2l':lrclass_r2l.predict_proba(x_test)[:,1],
                 'u2r_r2l':lrclass_u2r_r2l.predict_proba(x_test)[:,1]}

# %%
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score

eventClasses = ['Normal','R2L']
eventClassesInd = [0,1]


yh_test_comb  = ((yprob_test_lr['dos'] + yprob_test_lr['probe'] + yprob_test_lr['u2r_r2l'])/3 > 7e-2).astype(int)

#Acuracia
accTest = accuracy_score(y_test_bin,yh_test_comb)

#Recall
recTest  = recall_score(y_test_bin,yh_test_comb)

#Precision
precTest  = precision_score(y_test_bin,yh_test_comb)

#f1 score
f1Test  = f1_score(y_test_bin,yh_test_comb)

testMetrics  = np.array([accTest, recTest, precTest, f1Test])

table = pd.DataFrame()
table['Teste'] = testMetrics
table.index = ["Acurácia", "Revocação", "Precisão","F1 Score"]
table

# %%
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score

eventClasses = ['Normal','R2L']
eventClassesInd = [0,1]

accTest,recTest,precTest,f1Test = ([],[],[],[])
alphaList = [5e-1,1e-1,7e-2,6e-2,5e-2,4e-2,3e-2,1e-2,5e-3,1e-3,5e-4]
for alpha in alphaList:
    yh_test_comb  = ((yprob_test_lr['dos'] + yprob_test_lr['probe'] + yprob_test_lr['u2r_r2l'])/3 > alpha).astype(int)

    #Acuracia
    accTest.append(accuracy_score(y_test_bin,yh_test_comb))

    #Recall
    recTest.append(recall_score(y_test_bin,yh_test_comb))

    #Precision
    precTest.append(precision_score(y_test_bin,yh_test_comb))

    #f1 score
    f1Test.append(f1_score(y_test_bin,yh_test_comb))


plt.semilogx(alphaList,accTest,alphaList,recTest,alphaList,precTest,alphaList,f1Test)
plt.grid()
plt.legend(['Acurácia','Revocação','Precisão','F1 Score'])

# %% [markdown]
# ## Rede Neural <a id='nn_classe'></a>

# %% [markdown]
# ### Treinamento

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense
from tensorflow.keras.metrics import Precision, Recall

# %%
n = 121
nnclass_dos     = Sequential([Dense(1024, activation="relu"),
                              BatchNormalization(),
                              Dropout(0.01),
                              Dense(1, activation="sigmoid")])
nnclass_probe   = Sequential([Dense(1024, activation="relu"),
                              BatchNormalization(),
                              Dropout(0.01),
                              Dense(1, activation="sigmoid")])
nnclass_u2r     = Sequential([Dense(1024, activation="relu"),
                              BatchNormalization(),
                              Dropout(0.01),
                              Dense(1, activation="sigmoid")])
nnclass_r2l     = Sequential([Dense(1024, activation="relu"),
                              BatchNormalization(),
                              Dropout(0.01),
                              Dense(1, activation="sigmoid")])
nnclass_u2r_r2l = Sequential([Dense(1024, activation="relu"),
                              BatchNormalization(),
                              Dropout(0.01),
                              Dense(1, activation="sigmoid")])

metrics = ["accuracy"]
nnclass_dos.compile(loss="binary_crossentropy", optimizer="adam", metrics=metrics)
nnclass_probe.compile(loss="binary_crossentropy", optimizer="sgd", metrics=metrics)
nnclass_u2r.compile(loss="binary_crossentropy", optimizer="sgd", metrics=metrics)
nnclass_r2l.compile(loss="binary_crossentropy", optimizer="sgd", metrics=metrics)
nnclass_u2r_r2l.compile(loss="binary_crossentropy", optimizer="sgd", metrics=metrics)

epochs = 500
verbose=1
batch_size = 64
print("Treinando DoS")
history_dos = nnclass_dos.fit(x_train_dos,y_train_dos, epochs=epochs, batch_size=batch_size, verbose=verbose)
print("Treinando Probe")
history_probe = nnclass_probe.fit(x_train_probe,y_train_probe, epochs=epochs, batch_size=batch_size, verbose=verbose)
print("Treinando U2R")
history_u2r = nnclass_u2r.fit(x_train_u2r,y_train_u2r, epochs=epochs, batch_size=batch_size, verbose=verbose)
print("Treinando R2L")
history_r2l = nnclass_r2l.fit(x_train_r2l,y_train_r2l, epochs=epochs, batch_size=batch_size, verbose=verbose)
print("Treinando U2R & R2L")
history_u2r_r2l = nnclass_u2r_r2l.fit(x_train_u2r_r2l,y_train_u2r_r2l, batch_size=batch_size, epochs=epochs, verbose=verbose)
print("Treinado!")

# %% [markdown]
# ### Avaliação - DoS

# %%
from sklearn.metrics import f1_score, precision_recall_fscore_support

eventClasses = ['Normal','DoS']
eventClassesInd = [0,1]

yh_test_dos = (nnclass_dos.predict(x_test_dos) > 1e-5).astype(int)

yh_train_dos = (nnclass_dos.predict(x_train_dos) > 5e-1).astype(int)

#Acuracia
accTrain = accuracy_score(y_train_dos,yh_train_dos)
accTest = accuracy_score(y_test_dos,yh_test_dos)

#Recall
recTrain = recall_score(y_train_dos,yh_train_dos)
recTest  = recall_score(y_test_dos,yh_test_dos)

#Precision
precTrain = precision_score(y_train_dos,yh_train_dos)
precTest  = precision_score(y_test_dos,yh_test_dos)

#f1 score
f1Train = f1_score(y_train_dos,yh_train_dos)
f1Test  = f1_score(y_test_dos,yh_test_dos)

trainMetrics = np.array([accTrain, recTrain, precTrain, f1Train])
testMetrics  = np.array([accTest, recTest, precTest, f1Test])

table = pd.DataFrame()
table['Treinamento'] = trainMetrics
table['Teste'] = testMetrics
table.index = ["Acurácia", "Revocação", "Precisão","F1 Score"]
table

# %%
pd.crosstab(y_test_dos, yh_test_dos, rownames=['Actual attacks'], colnames=['Predicted attacks'])

# %% [markdown]
# ### Avaliação - Probe

# %%
from sklearn.metrics import f1_score, precision_recall_fscore_support

eventClasses = ['Normal','Probe']
eventClassesInd = [0,1]

yh_test_probe = (nnclass_probe.predict(x_test_probe) > 1e-2).astype(int)

yh_train_probe = (nnclass_probe.predict(x_train_probe) > 5e-1).astype(int)

#Acuracia
accTrain = accuracy_score(y_train_probe,yh_train_probe)
accTest = accuracy_score(y_test_probe,yh_test_probe)

#Recall
recTrain = recall_score(y_train_probe,yh_train_probe)
recTest  = recall_score(y_test_probe,yh_test_probe)

#Precision
precTrain = precision_score(y_train_probe,yh_train_probe)
precTest  = precision_score(y_test_probe,yh_test_probe)

#f1 score
f1Train = f1_score(y_train_probe,yh_train_probe)
f1Test  = f1_score(y_test_probe,yh_test_probe)

trainMetrics = np.array([accTrain, recTrain, precTrain, f1Train])
testMetrics  = np.array([accTest, recTest, precTest, f1Test])

table = pd.DataFrame()
table['Treinamento'] = trainMetrics
table['Teste'] = testMetrics
table.index = ["Acurácia", "Revocação", "Precisão","F1 Score"]
table

# %%
pd.crosstab(y_test_probe, yh_test_probe, rownames=['Actual attacks'], colnames=['Predicted attacks'])

# %% [markdown]
# ### Avaliação - U2R

# %%
from sklearn.metrics import f1_score, precision_recall_fscore_support

eventClasses = ['Normal','U2R']
eventClassesInd = [0,1]

yh_test_u2r = (nnclass_u2r.predict(x_test_u2r) > 1e-3).astype(int)

yh_train_u2r = (nnclass_u2r.predict(x_train_u2r) > 5e-1).astype(int)

#Acuracia
accTrain = accuracy_score(y_train_u2r,yh_train_u2r)
accTest = accuracy_score(y_test_u2r,yh_test_u2r)

#Recall
recTrain = recall_score(y_train_u2r,yh_train_u2r)
recTest  = recall_score(y_test_u2r,yh_test_u2r)

#Precision
precTrain = precision_score(y_train_u2r,yh_train_u2r)
precTest  = precision_score(y_test_u2r,yh_test_u2r)

#f1 score
f1Train = f1_score(y_train_u2r,yh_train_u2r)
f1Test  = f1_score(y_test_u2r,yh_test_u2r)

trainMetrics = np.array([accTrain, recTrain, precTrain, f1Train])
testMetrics  = np.array([accTest, recTest, precTest, f1Test])

table = pd.DataFrame()
table['Treinamento'] = trainMetrics
table['Teste'] = testMetrics
table.index = ["Acurácia", "Revocação", "Precisão","F1 Score"]
table

# %%
pd.crosstab(y_test_u2r, yh_test_u2r, rownames=['Actual attacks'], colnames=['Predicted attacks'])

# %% [markdown]
# ### Avaliação - R2L

# %%
from sklearn.metrics import f1_score, precision_recall_fscore_support

eventClasses = ['Normal','R2L']
eventClassesInd = [0,1]

yh_test_r2l = (nnclass_r2l.predict(x_test_r2l) > 1e-3).astype(int)

yh_train_r2l = (nnclass_r2l.predict(x_train_r2l) > 5e-1).astype(int)

#Acuracia
accTrain = accuracy_score(y_train_r2l,yh_train_r2l)
accTest = accuracy_score(y_test_r2l,yh_test_r2l)

#Recall
recTrain = recall_score(y_train_r2l,yh_train_r2l)
recTest  = recall_score(y_test_r2l,yh_test_r2l)

#Precision
precTrain = precision_score(y_train_r2l,yh_train_r2l)
precTest  = precision_score(y_test_r2l,yh_test_r2l)

#f1 score
f1Train = f1_score(y_train_r2l,yh_train_r2l)
f1Test  = f1_score(y_test_r2l,yh_test_r2l)

trainMetrics = np.array([accTrain, recTrain, precTrain, f1Train])
testMetrics  = np.array([accTest, recTest, precTest, f1Test])

table = pd.DataFrame()
table['Treinamento'] = trainMetrics
table['Teste'] = testMetrics
table.index = ["Acurácia", "Revocação", "Precisão","F1 Score"]
table

# %%
pd.crosstab(y_test_r2l, yh_test_r2l.flatten(), rownames=['Actual attacks'], colnames=['Predicted attacks'])

# %% [markdown]
# ### Avaliação - U2R + R2L

# %%
from sklearn.metrics import f1_score, precision_recall_fscore_support

eventClasses = ['Normal','R2L']
eventClassesInd = [0,1]

yh_test_u2r_r2l = (nnclass_u2r_r2l.predict(x_test_u2r_r2l) > 1e-3).astype(int)

yh_train_u2r_r2l = (nnclass_u2r_r2l.predict(x_train_u2r_r2l) > 5e-1).astype(int)

#Acuracia
accTrain = accuracy_score(y_train_u2r_r2l,yh_train_u2r_r2l)
accTest = accuracy_score(y_test_u2r_r2l,yh_test_u2r_r2l)

#Recall
recTrain = recall_score(y_train_u2r_r2l,yh_train_u2r_r2l)
recTest  = recall_score(y_test_u2r_r2l,yh_test_u2r_r2l)

#Precision
precTrain = precision_score(y_train_u2r_r2l,yh_train_u2r_r2l)
precTest  = precision_score(y_test_u2r_r2l,yh_test_u2r_r2l)

#f1 score
f1Train = f1_score(y_train_u2r_r2l,yh_train_u2r_r2l)
f1Test  = f1_score(y_test_u2r_r2l,yh_test_u2r_r2l)

trainMetrics = np.array([accTrain, recTrain, precTrain, f1Train])
testMetrics  = np.array([accTest, recTest, precTest, f1Test])

table = pd.DataFrame()
table['Treinamento'] = trainMetrics
table['Teste'] = testMetrics
table.index = ["Acurácia", "Revocação", "Precisão","F1 Score"]
table

# %%
pd.crosstab(y_test_u2r_r2l, yh_test_u2r_r2l.flatten(), rownames=['Actual attacks'], colnames=['Predicted attacks'])

# %% [markdown]
# ### Combinação dos classificadores

# %%
yprob_train_nn = {'dos':nnclass_dos.predict(x_train),
                  'probe':nnclass_probe.predict(x_train),
                  'u2r':nnclass_u2r.predict(x_train),
                  'r2l':nnclass_r2l.predict(x_train),
                  'u2r_r2l':nnclass_u2r_r2l.predict(x_train)}

yprob_test_nn = {'dos':nnclass_dos.predict(x_test),
                 'probe':nnclass_probe.predict(x_test),
                 'u2r':nnclass_u2r.predict(x_test),
                 'r2l':nnclass_r2l.predict(x_test),
                 'u2r_r2l':nnclass_u2r_r2l.predict(x_test)}

# %%
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score

eventClasses = ['Normal','R2L']
eventClassesInd = [0,1]


yh_test_comb  = ((yprob_test_nn['dos'] + yprob_test_nn['probe'] + yprob_test_nn['u2r_r2l'])/3 > 3e-5).astype(int)

#Acuracia
accTest = accuracy_score(y_test_bin,yh_test_comb)

#Recall
recTest  = recall_score(y_test_bin,yh_test_comb)

#Precision
precTest  = precision_score(y_test_bin,yh_test_comb)

#f1 score
f1Test  = f1_score(y_test_bin,yh_test_comb)

testMetrics  = np.array([accTest, recTest, precTest, f1Test])

table = pd.DataFrame()
table['Teste'] = testMetrics
table.index = ["Acurácia", "Revocação", "Precisão","F1 Score"]
table

# %%
pd.crosstab(y_test_bin, yh_test_comb.flatten(), rownames=['Actual attacks'], colnames=['Predicted attacks'])

# %% [markdown]
# # Classificação Binária (Ataque - Normal)

# %% [markdown]
# ## Random Forest

# %%
(x_train_bin, y_train_bin) = (df_train_ar.loc[:, filtered_features], df_train_ar.class2)

(x_cv_bin, y_cv_bin) = (df_cv_ar.loc[:, filtered_features], df_cv_ar.class2)

(x_test_bin, y_test_bin) = (df_test_ar.loc[:, filtered_features], df_test_ar.class2)

# %%
(x_train_bin, y_train_bin) = (df_train_sc[features_sc], df_train_sc.class2)

(x_cv_bin, y_cv_bin) = (df_cv_sc[features_sc], df_cv_sc.class2)

(x_test_bin, y_test_bin) = (df_test_sc[features_sc], df_test_sc.class2)

# %%
from sklearn.ensemble import RandomForestClassifier

rf_clf = RandomForestClassifier(n_estimators=400, max_depth=20, random_state=10000)
rf_clf.fit(x_train_bin,y_train_bin)

beep()

# %%
yprob_train_bin = rf_clf.predict_proba(x_train_bin)[:,1]
yprob_cv_bin    = rf_clf.predict_proba(x_cv_bin)[:,1]
yprob_test_bin  = rf_clf.predict_proba(x_test_bin)[:,1]

# %%
from sklearn.metrics import accuracy_score, roc_curve, roc_auc_score, f1_score, precision_score

#Metric analyses for the cv dataset for different thresholds
# %matplotlib inline
analyseThresholds(y_cv_bin,yprob_cv_bin)

# %%
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score, roc_curve, roc_auc_score

yh_train_bin = yprob_train_bin > 0.5
yh_cv_bin    = yprob_cv_bin > 0.27
yh_test_bin  = yprob_test_bin > 0.27

printMetrics([(y_train_bin,yh_train_bin),(y_cv_bin,yh_cv_bin),(y_test_bin,yh_test_bin)],["Trainning","CV","Test"])
# Out:
#           Trainning        CV      Test
# Accuracy   0.999742  0.993888  0.860983
# TPR        0.999531  0.990333  0.879919
# FPR        0.000074  0.003036  0.164041
# AUC        0.999729  0.993649  0.857939
# F1 Score   0.999723  0.993392  0.878140
# Precisão   0.999915  0.996471  0.876368

# %% [markdown]
# ## Regressão Logística <a id='lr_bin'></a>

# %% [markdown]
# ### Treinamento

# %%
from sklearn.linear_model import LogisticRegression
import time

# %%
t1 = time.time()

lrclass_bin = LogisticRegression()
lrclass_bin.fit(x_train_bin,y_train_bin)

print("Tempo: %.1f s" % (time.time() - t1))

# %% [markdown]
# ### Avaliação

# %%
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score

eventClasses = ['Normal','Ataque']
eventClassesInd = [0,1]

yh_train_bin = lrclass_bin.predict(x_train_bin)
yh_test_bin  = lrclass_bin.predict(x_test_bin)

#Acuracia
accTrain = accuracy_score(y_train_bin,yh_train_bin)
accTest = accuracy_score(y_test_bin,yh_test_bin)

#Recall
recTrain = recall_score(y_train_bin,yh_train_bin)
recTest  = recall_score(y_test_bin,yh_test_bin)

#Precision
precTrain = precision_score(y_train_bin,yh_train_bin)
precTest  = precision_score(y_test_bin,yh_test_bin)

#f1 score
f1Train = f1_score(y_train_bin,yh_train_bin)
f1Test  = f1_score(y_test_bin,yh_test_bin)

trainMetrics = np.array([accTrain, recTrain, precTrain, f1Train])
testMetrics  = np.array([accTest, recTest, precTest, f1Test])

table = pd.DataFrame()
table['Treinamento'] = trainMetrics
table['Teste'] = testMetrics
table.index = ["Acurácia", "Revocação", "Precisão","F1 Score"]
table

# %%
from sklearn.metrics import plot_confusion_matrix
plot_confusion_matrix(lrclass_bin,x_test_bin,y_test_bin)

# %% [markdown]
# ## SVM <a id='svm_bin'></a>

# %% [markdown]
# ### Treinamento

# %%
from sklearn import svm

t1 = time.time()

svmclass_bin = svm.SVC(kernel='linear', C=1.0, random_state=0)

svmclass_bin.fit(x_train_bin,y_train_bin)


print("Tempo: %.1f s" % (time.time()-t1))

# %% [markdown]
# ### Avaliação

# %%
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score

eventClasses = ['Normal','DoS']
eventClassesInd = [0,1]

yh_train_bin = svmclass_bin.predict(x_train_bin)
yh_test_bin  = svmclass_bin.predict(x_test_bin)

#Acuracia
accTrain = accuracy_score(y_train_bin,yh_train_bin)
accTest = accuracy_score(y_test_bin,yh_test_bin)

#Recall
recTrain = recall_score(y_train_bin,yh_train_bin)
recTest  = recall_score(y_test_bin,yh_test_bin)

#Precision
precTrain = precision_score(y_train_bin,yh_train_bin)
precTest  = precision_score(y_test_bin,yh_test_bin)

#f1 score
f1Train = f1_score(y_train_bin,yh_train_bin)
f1Test  = f1_score(y_test_bin,yh_test_bin)

trainMetrics = np.array([accTrain, recTrain, precTrain, f1Train])
testMetrics  = np.array([accTest, recTest, precTest, f1Test])

table = pd.DataFrame()
table['Treinamento'] = trainMetrics
table['Teste'] = testMetrics
table.index = ["Acurácia", "Revocação", "Precisão","F1 Score"]
table

# %%
from sklearn.metrics import plot_confusion_matrix
plot_confusion_matrix(svmclass_bin,x_test_bin,y_test_bin)

# %% [markdown]
# ## Rede Neural<a id='nn_bin'></a>

# %% [markdown]
# ### Treinamento

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.metrics import Precision, Recall

# %%
'''
nnclass_bin     = Sequential([Dense(1024, activation="relu"),
                              BatchNormalization(),
                              Dropout(0.01),
                              Dense(768, activation="relu"),
                              BatchNormalization(),
                              Dropout(0.01),
                              Dense(512, activation="relu"),
                              BatchNormalization(),
                              Dropout(0.01),
                              Dense(256, activation="relu"),
                              BatchNormalization(),
                              Dropout(0.01),
                              Dense(128, activation="relu"),
                              BatchNormalization(),
                              Dropout(0.01),
                              Dense(1, activation="sigmoid")])

metrics = ["accuracy"]
nnclass_bin.compile(loss="binary_crossentropy", optimizer="adam", metrics=metrics)

epochs = 500
verbose=1
history_bin = nnclass_bin.fit(x_train_bin,y_train_bin, epochs=epochs, batch_size=64, verbose=verbose)
'''
None

# %%
nnclass_bin     = Sequential([Dense(1024, activation="relu"),
                              BatchNormalization(),
                              Dropout(0.01),
                              Dense(1, activation="sigmoid")])

metrics = ["accuracy"]
nnclass_bin.compile(loss="binary_crossentropy", optimizer="adam", metrics=metrics)

epochs = 2
verbose=1
history_bin = nnclass_bin.fit(x_train_bin,y_train_bin, epochs=epochs, batch_size=64, verbose=verbose)

# %% [markdown]
# ### Avaliação

# %%
from sklearn.metrics import f1_score, precision_recall_fscore_support

eventClasses = ['Normal','Ataque']
eventClassesInd = [0,1]

threshold = 0.1
yh_test_bin = (nnclass_bin.predict(x_test_bin) > threshold).astype(int)
#yh_test_bin = np.argmax(yh_test_bin,axis=1)

yh_train_bin = (nnclass_bin.predict(x_train_bin) > threshold).astype(int)
#yh_train_bin = np.argmax(yh_train_bin,axis=1)

#Acuracia
accTrain = accuracy_score(y_train_bin,yh_train_bin)
accTest = accuracy_score(y_test_bin,yh_test_bin)

#Recall
recTrain = recall_score(y_train_bin,yh_train_bin)
recTest  = recall_score(y_test_bin,yh_test_bin)

#Precision
precTrain = precision_score(y_train_bin,yh_train_bin)
precTest  = precision_score(y_test_bin,yh_test_bin)

#f1 score
f1Train = f1_score(y_train_bin,yh_train_bin)
f1Test  = f1_score(y_test_bin,yh_test_bin)

trainMetrics = np.array([accTrain, recTrain, precTrain, f1Train])
testMetrics  = np.array([accTest, recTest, precTest, f1Test])

table = pd.DataFrame()
table['Treinamento'] = trainMetrics
table['Teste'] = testMetrics
table.index = ["Acurácia", "Revocação", "Precisão","F1 Score"]
table

# %%
pd.crosstab(y_test_bin, yh_test_bin.flatten(), rownames=['Actual attacks'], colnames=['Predicted attacks'])

# %% [markdown]
# ## Decision Tree

# %% [markdown]
# ### Trainning

# %%
from sklearn.tree import DecisionTreeClassifier

treeclass_bin = DecisionTreeClassifier(max_depth=4)
treeclass_bin.fit(x_train_bin,y_train_bin)

# %%
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score

eventClasses = ['Normal','DoS']
eventClassesInd = [0,1]

yh_train_bin = treeclass_bin.predict_proba(x_train_bin)[:,1] > 0.5
yh_test_bin  = treeclass_bin.predict_proba(x_test_bin)[:,1] > 0.1

#Acuracia
accTrain = accuracy_score(y_train_bin,yh_train_bin)
accTest = accuracy_score(y_test_bin,yh_test_bin)

#Recall
recTrain = recall_score(y_train_bin,yh_train_bin)
recTest  = recall_score(y_test_bin,yh_test_bin)

#Precision
precTrain = precision_score(y_train_bin,yh_train_bin)
precTest  = precision_score(y_test_bin,yh_test_bin)

#f1 score
f1Train = f1_score(y_train_bin,yh_train_bin)
f1Test  = f1_score(y_test_bin,yh_test_bin)

trainMetrics = np.array([accTrain, recTrain, precTrain, f1Train])
testMetrics  = np.array([accTest, recTest, precTest, f1Test])

table = pd.DataFrame()
table['Treinamento'] = trainMetrics
table['Teste'] = testMetrics
table.index = ["Acurácia", "Revocação", "Precisão","F1 Score"]
table

# %%
total = 20
listDepths = list(range(1,total+1))
(accTest,recTest,precTest,f1Test) = ([],[],[],[])

for depth in range(1,total+1):
    print("Iteration ", depth," of ",total)
    treeclass_bin = DecisionTreeClassifier(max_depth=depth)
    treeclass_bin.fit(x_train_bin,y_train_bin)

    eventClasses = ['Normal','DoS']
    eventClassesInd = [0,1]

    #yh_train_bin = treeclass_bin.predict(x_train_bin)
    yh_test_bin = treeclass_bin.predict(x_test_bin)

    #Acuracia
    #accTrain = accuracy_score(y_train_bin,yh_train_bin)
    accTest.append(accuracy_score(y_test_bin,yh_test_bin))

    #Recall
    #recTrain = recall_score(y_train_bin,yh_train_bin)
    recTest.append(recall_score(y_test_bin,yh_test_bin))

    #Precision
    #precTrain = precision_score(y_train_bin,yh_train_bin)
    precTest.append(precision_score(y_test_bin,yh_test_bin))

    #f1 score
    #f1Train = f1_score(y_train_bin,yh_train_bin)
    f1Test.append(f1_score(y_test_bin,yh_test_bin))

plt.plot(listDepths,accTest,listDepths,recTest,listDepths,precTest,listDepths,f1Test)
plt.grid()
plt.legend(["Acc","Rec","Prec","F1"])
plt.show()
